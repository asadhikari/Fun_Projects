# %%
#import the required libraries
from wordcloud import WordCloud, STOPWORDS
# %matplotlib inline
import urllib.request
import requests
from bs4 import BeautifulSoup

# %%
#get the link
link = "https://en.wikipedia.org/wiki/Machine_learning"

#convert the html to text
html = requests.get(link).text
soup = BeautifulSoup(html, "lxml")
text = soup.get_text()

# %%
#Convert the text to a string
unique_string=("").join(text)

# %%
#Make the word cloud
#width and height define the aspect ratio of the figure
wordcloud = WordCloud(width = 1000, height = 1000,background_color ='black',colormap = 'rainbow', stopwords = STOPWORDS).generate(str(unique_string));

#plot it 
fig = plt.figure(figsize=(12,12))
plt.axis("off")
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.show()
#save the file
wordcloud.to_file("ML.png")
